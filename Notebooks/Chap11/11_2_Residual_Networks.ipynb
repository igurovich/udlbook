# %% [markdown]
# <a href="https://colab.research.google.com/github/igurovich/udlbook/blob/main/Notebooks/Chap11/11_2_Residual_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 11.2: Residual Networks**
#
# This notebook adapts the networks for MNIST1D to use residual connections.
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-hkwg6tl9
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-hkwg6tl9
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.61.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.11.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=6fbc01357542fba9b9e870874ca0d83ff6ab8cdabbfa9478f9613b9ffe229136
#   Stored in directory: /tmp/pip-ephem-wheel-cache-0goojh9p/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import numpy as np
import os
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import matplotlib.pyplot as plt
import mnist1d
import random

# %%
args = mnist1d.data.get_dataset_args()
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=False)

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Length of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 1000
# Length of each example: 40

# %%
# Load in the data
train_data_x = data['x'].transpose()
train_data_y = data['y']
val_data_x = data['x_test'].transpose()
val_data_y = data['y_test']
# Print out sizes
print("Train data: %d examples (columns), each of which has %d dimensions (rows)"%((train_data_x.shape[1],train_data_x.shape[0])))
print("Validation data: %d examples (columns), each of which has %d dimensions (rows)"%((val_data_x.shape[1],val_data_x.shape[0])))
# Out:
# Train data: 4000 examples (columns), each of which has 40 dimensions (rows)
# Validation data: 1000 examples (columns), each of which has 40 dimensions (rows)

# %% [markdown]
# Define the network

# %%
# There are 40 input dimensions and 10 output dimensions for this data
# The inputs correspond to the 40 offsets in the MNIST1D template.
D_i = 40
# The outputs correspond to the 10 digits
D_o = 10


# We will adapt this model to have residual connections around the linear layers
# This is the same model we used in practical 8.1, but we can't use the sequential
# class for residual networks (which aren't strictly sequential).  Hence, I've rewritten
# it as a model that inherits from a base class

class ResidualNetwork(torch.nn.Module):
  def __init__(self, input_size, output_size, hidden_size=100):
    super(ResidualNetwork, self).__init__()
    self.linear1 = nn.Linear(input_size, hidden_size)
    self.linear2 = nn.Linear(hidden_size, hidden_size)
    self.linear3 = nn.Linear(hidden_size, hidden_size)
    self.linear4 = nn.Linear(hidden_size, output_size)
    print("Initialized MLPBase model with {} parameters".format(self.count_params()))

  def count_params(self):
    return sum([p.view(-1).shape[0] for p in self.parameters()])

# TODO -- Add residual connections to this model
# The order of operations within each block should similar to figure 11.5b
# ie., linear1 first, ReLU+linear2 in first residual block, ReLU+linear3 in second residual block), linear4 at end
# Replace this function
  def forward(self, x):
    # h1 = self.linear1(x).relu()
    # h2 =  self.linear2(h1).relu()
    # h3 =  self.linear3(h2).relu()

    h1 = self.linear1(x)
    h2 = h1 + self.linear2(h1).relu()
    h3 = h2 + self.linear3(h2).relu()
    return self.linear4(h3)

# %%
# He initialization of weights
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# %%
#Define the model
model = ResidualNetwork(40, 10)

# choose cross entropy loss function (equation 5.24 in the loss notes)
loss_function = nn.CrossEntropyLoss()
# construct SGD optimizer and initialize learning rate and momentum
optimizer = torch.optim.SGD(model.parameters(), lr = 0.05, momentum=0.9)
# object that decreases learning rate by half every 20 epochs
scheduler = StepLR(optimizer, step_size=20, gamma=0.5)
# convert data to torch tensors
x_train = torch.tensor(train_data_x.transpose().astype('float32'))
y_train = torch.tensor(train_data_y.astype('long'))
x_val= torch.tensor(val_data_x.transpose().astype('float32'))
y_val = torch.tensor(val_data_y.astype('long'))

# load the data into a class that creates the batches
data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

# Initialize model weights
model.apply(weights_init)

# loop over the dataset n_epoch times
n_epoch = 100
# store the loss and the % correct at each epoch
losses_train = np.zeros((n_epoch))
errors_train = np.zeros((n_epoch))
losses_val = np.zeros((n_epoch))
errors_val = np.zeros((n_epoch))

for epoch in range(n_epoch):
  # loop over batches
  for i, data in enumerate(data_loader):
    # retrieve inputs and labels for this batch
    x_batch, y_batch = data
    # zero the parameter gradients
    optimizer.zero_grad()
    # forward pass -- calculate model output
    pred = model(x_batch)
    # compute the loss
    loss = loss_function(pred, y_batch)
    # backward pass
    loss.backward()
    # SGD update
    optimizer.step()

  # Run whole dataset to get statistics -- normally wouldn't do this
  pred_train = model(x_train)
  pred_val = model(x_val)
  _, predicted_train_class = torch.max(pred_train.data, 1)
  _, predicted_val_class = torch.max(pred_val.data, 1)
  errors_train[epoch] = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
  errors_val[epoch]= 100 - 100 * (predicted_val_class == y_val).float().sum() / len(y_val)
  losses_train[epoch] = loss_function(pred_train, y_train).item()
  losses_val[epoch]= loss_function(pred_val, y_val).item()
  print(f'Epoch {epoch:5d}, train loss {losses_train[epoch]:.6f}, train error {errors_train[epoch]:3.2f},  val loss {losses_val[epoch]:.6f}, percent error {errors_val[epoch]:3.2f}')

  # tell scheduler to consider updating learning rate
  scheduler.step()
# Out:
# Initialized MLPBase model with 25310 parameters
# Epoch     0, train loss 1.595186, train error 59.35,  val loss 1.740050, percent error 65.20
# Epoch     1, train loss 1.119265, train error 41.47,  val loss 1.294359, percent error 50.20
# Epoch     2, train loss 0.988395, train error 36.75,  val loss 1.217057, percent error 44.30
# Epoch     3, train loss 0.871672, train error 32.62,  val loss 1.157416, percent error 45.60
# Epoch     4, train loss 0.836308, train error 30.95,  val loss 1.264741, percent error 44.90
# Epoch     5, train loss 0.759562, train error 28.25,  val loss 1.183586, percent error 42.40
# Epoch     6, train loss 0.673300, train error 24.12,  val loss 1.199117, percent error 42.80
# Epoch     7, train loss 0.599425, train error 21.88,  val loss 1.178579, percent error 42.00
# Epoch     8, train loss 0.588486, train error 22.45,  val loss 1.239538, percent error 40.80
# Epoch     9, train loss 0.487365, train error 17.68,  val loss 1.155787, percent error 41.00
# Epoch    10, train loss 0.447450, train error 16.32,  val loss 1.219290, percent error 38.20
# Epoch    11, train loss 0.458444, train error 17.30,  val loss 1.305532, percent error 39.00
# Epoch    12, train loss 0.363750, train error 13.50,  val loss 1.260974, percent error 38.20
# Epoch    13, train loss 0.437073, train error 15.65,  val loss 1.511826, percent error 40.10
# Epoch    14, train loss 0.340996, train error 12.55,  val loss 1.303563, percent error 38.00
# Epoch    15, train loss 0.356946, train error 12.55,  val loss 1.454441, percent error 36.60
# Epoch    16, train loss 0.325353, train error 11.90,  val loss 1.550654, percent error 38.60
# Epoch    17, train loss 0.403410, train error 13.28,  val loss 1.544153, percent error 38.50
# Epoch    18, train loss 0.395222, train error 14.10,  val loss 1.541647, percent error 37.00
# Epoch    19, train loss 0.438991, train error 14.50,  val loss 1.787502, percent error 39.50
# Epoch    20, train loss 0.102164, train error 2.90,  val loss 1.336099, percent error 32.90
# Epoch    21, train loss 0.047082, train error 0.43,  val loss 1.273352, percent error 32.00
# Epoch    22, train loss 0.029479, train error 0.12,  val loss 1.311263, percent error 32.50
# Epoch    23, train loss 0.021181, train error 0.03,  val loss 1.310596, percent error 32.50
# Epoch    24, train loss 0.015847, train error 0.00,  val loss 1.333200, percent error 31.90
# Epoch    25, train loss 0.013800, train error 0.00,  val loss 1.351314, percent error 30.80
# Epoch    26, train loss 0.012121, train error 0.00,  val loss 1.365779, percent error 30.70
# Epoch    27, train loss 0.010789, train error 0.00,  val loss 1.384798, percent error 31.20
# Epoch    28, train loss 0.009732, train error 0.00,  val loss 1.397826, percent error 30.70
# Epoch    29, train loss 0.008929, train error 0.00,  val loss 1.415902, percent error 31.50
# Epoch    30, train loss 0.008265, train error 0.00,  val loss 1.429496, percent error 30.80
# Epoch    31, train loss 0.007760, train error 0.00,  val loss 1.442432, percent error 31.10
# Epoch    32, train loss 0.007135, train error 0.00,  val loss 1.458780, percent error 31.70
# Epoch    33, train loss 0.006680, train error 0.00,  val loss 1.465394, percent error 31.90
# Epoch    34, train loss 0.006288, train error 0.00,  val loss 1.477363, percent error 31.90
# Epoch    35, train loss 0.005933, train error 0.00,  val loss 1.486721, percent error 31.80
# Epoch    36, train loss 0.005621, train error 0.00,  val loss 1.498042, percent error 31.90
# Epoch    37, train loss 0.005337, train error 0.00,  val loss 1.508949, percent error 31.70
# Epoch    38, train loss 0.005087, train error 0.00,  val loss 1.515855, percent error 31.40
# Epoch    39, train loss 0.004843, train error 0.00,  val loss 1.524988, percent error 31.80
# Epoch    40, train loss 0.004725, train error 0.00,  val loss 1.529717, percent error 31.70
# Epoch    41, train loss 0.004622, train error 0.00,  val loss 1.532905, percent error 31.80
# Epoch    42, train loss 0.004524, train error 0.00,  val loss 1.537377, percent error 31.70
# Epoch    43, train loss 0.004429, train error 0.00,  val loss 1.541111, percent error 31.70
# Epoch    44, train loss 0.004341, train error 0.00,  val loss 1.543901, percent error 31.70
# Epoch    45, train loss 0.004254, train error 0.00,  val loss 1.548450, percent error 31.80
# Epoch    46, train loss 0.004170, train error 0.00,  val loss 1.551533, percent error 31.80
# Epoch    47, train loss 0.004091, train error 0.00,  val loss 1.556961, percent error 31.80
# Epoch    48, train loss 0.004013, train error 0.00,  val loss 1.559269, percent error 31.50
# Epoch    49, train loss 0.003942, train error 0.00,  val loss 1.563720, percent error 31.60
# Epoch    50, train loss 0.003866, train error 0.00,  val loss 1.566264, percent error 31.50
# Epoch    51, train loss 0.003797, train error 0.00,  val loss 1.569444, percent error 31.60
# Epoch    52, train loss 0.003729, train error 0.00,  val loss 1.573171, percent error 31.50
# Epoch    53, train loss 0.003663, train error 0.00,  val loss 1.575793, percent error 31.30
# Epoch    54, train loss 0.003601, train error 0.00,  val loss 1.580382, percent error 31.50
# Epoch    55, train loss 0.003540, train error 0.00,  val loss 1.582814, percent error 31.50
# Epoch    56, train loss 0.003481, train error 0.00,  val loss 1.586173, percent error 31.40
# Epoch    57, train loss 0.003425, train error 0.00,  val loss 1.589159, percent error 31.40
# Epoch    58, train loss 0.003370, train error 0.00,  val loss 1.592062, percent error 31.60
# Epoch    59, train loss 0.003316, train error 0.00,  val loss 1.595008, percent error 31.40
# Epoch    60, train loss 0.003288, train error 0.00,  val loss 1.596455, percent error 31.60
# Epoch    61, train loss 0.003262, train error 0.00,  val loss 1.598263, percent error 31.50
# Epoch    62, train loss 0.003237, train error 0.00,  val loss 1.598708, percent error 31.60
# Epoch    63, train loss 0.003212, train error 0.00,  val loss 1.601081, percent error 31.50
# Epoch    64, train loss 0.003188, train error 0.00,  val loss 1.602584, percent error 31.50
# Epoch    65, train loss 0.003164, train error 0.00,  val loss 1.603427, percent error 31.60
# Epoch    66, train loss 0.003140, train error 0.00,  val loss 1.605825, percent error 31.50
# Epoch    67, train loss 0.003117, train error 0.00,  val loss 1.606319, percent error 31.60
# Epoch    68, train loss 0.003094, train error 0.00,  val loss 1.608117, percent error 31.60
# Epoch    69, train loss 0.003071, train error 0.00,  val loss 1.609590, percent error 31.50
# Epoch    70, train loss 0.003049, train error 0.00,  val loss 1.610683, percent error 31.70
# Epoch    71, train loss 0.003027, train error 0.00,  val loss 1.612292, percent error 31.60
# Epoch    72, train loss 0.003005, train error 0.00,  val loss 1.613364, percent error 31.50
# Epoch    73, train loss 0.002983, train error 0.00,  val loss 1.614691, percent error 31.50
# Epoch    74, train loss 0.002961, train error 0.00,  val loss 1.616322, percent error 31.60
# Epoch    75, train loss 0.002941, train error 0.00,  val loss 1.617221, percent error 31.60
# Epoch    76, train loss 0.002920, train error 0.00,  val loss 1.619345, percent error 31.60
# Epoch    77, train loss 0.002900, train error 0.00,  val loss 1.620192, percent error 31.60
# Epoch    78, train loss 0.002879, train error 0.00,  val loss 1.622135, percent error 31.60
# Epoch    79, train loss 0.002860, train error 0.00,  val loss 1.622603, percent error 31.60
# Epoch    80, train loss 0.002849, train error 0.00,  val loss 1.623681, percent error 31.60
# Epoch    81, train loss 0.002840, train error 0.00,  val loss 1.624367, percent error 31.60
# Epoch    82, train loss 0.002830, train error 0.00,  val loss 1.624885, percent error 31.60
# Epoch    83, train loss 0.002820, train error 0.00,  val loss 1.625599, percent error 31.60
# Epoch    84, train loss 0.002811, train error 0.00,  val loss 1.626140, percent error 31.60
# Epoch    85, train loss 0.002802, train error 0.00,  val loss 1.626939, percent error 31.70
# Epoch    86, train loss 0.002792, train error 0.00,  val loss 1.627763, percent error 31.60
# Epoch    87, train loss 0.002782, train error 0.00,  val loss 1.628152, percent error 31.70
# Epoch    88, train loss 0.002773, train error 0.00,  val loss 1.628804, percent error 31.60
# Epoch    89, train loss 0.002764, train error 0.00,  val loss 1.629537, percent error 31.60
# Epoch    90, train loss 0.002755, train error 0.00,  val loss 1.630063, percent error 31.70
# Epoch    91, train loss 0.002746, train error 0.00,  val loss 1.630905, percent error 31.70
# Epoch    92, train loss 0.002737, train error 0.00,  val loss 1.631455, percent error 31.70
# Epoch    93, train loss 0.002728, train error 0.00,  val loss 1.632065, percent error 31.70
# Epoch    94, train loss 0.002719, train error 0.00,  val loss 1.632850, percent error 31.70
# Epoch    95, train loss 0.002710, train error 0.00,  val loss 1.633308, percent error 31.70
# Epoch    96, train loss 0.002701, train error 0.00,  val loss 1.634096, percent error 31.70
# Epoch    97, train loss 0.002692, train error 0.00,  val loss 1.634763, percent error 31.70
# Epoch    98, train loss 0.002683, train error 0.00,  val loss 1.635266, percent error 31.70
# Epoch    99, train loss 0.002675, train error 0.00,  val loss 1.636097, percent error 31.70

# %%
# Plot the results
fig, ax = plt.subplots()
ax.plot(errors_train,'r-',label='train')
ax.plot(errors_val,'b-',label='test')
ax.set_ylim(0,100); ax.set_xlim(0,n_epoch)
ax.set_xlabel('Epoch'); ax.set_ylabel('Error')
ax.set_title('TrainError %3.2f, Val Error %3.2f'%(errors_train[-1],errors_val[-1]))
ax.legend()
plt.show()

# %% [markdown]
# The primary motivation of residual networks is to allow training of much deeper networks.
#
# TODO: Try running this network with and without the residual connections.  Does adding the residual connections change the performance?
