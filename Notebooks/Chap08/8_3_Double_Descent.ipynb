# %% [markdown]
# <a href="https://colab.research.google.com/github/igurovich/udlbook/blob/main/Notebooks/Chap08/8_3_Double_Descent.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Notebook 8.3: Double Descent**
#
# This notebook investigates double descent as described in section 8.4 of the book.
#
# It uses the MNIST-1D database which can be found at https://github.com/greydanus/mnist1d
#
# Work through the cells below, running each cell in turn. In various places you will see the words "TODO". Follow the instructions at these places and make predictions about what is going to happen or write code to complete the functions.
#
# Contact me at udlbookmail@gmail.com if you find any mistakes or have any suggestions.

# %%
# Run this if you're in a Colab to install MNIST 1D repository
# !pip install git+https://github.com/greydanus/mnist1d
# Out:
# Collecting git+https://github.com/greydanus/mnist1d
#   Cloning https://github.com/greydanus/mnist1d to /tmp/pip-req-build-saj0ra75
#   Running command git clone --filter=blob:none --quiet https://github.com/greydanus/mnist1d /tmp/pip-req-build-saj0ra75
#   Resolved https://github.com/greydanus/mnist1d to commit 7878d96082abd200c546a07a4101fa90b30fdf7e
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.32.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (2.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (3.10.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.12/dist-packages (from mnist1d==0.0.2.post16) (1.16.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib->mnist1d==0.0.2.post16) (2.9.0.post0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->mnist1d==0.0.2.post16) (2025.11.12)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib->mnist1d==0.0.2.post16) (1.17.0)
# Building wheels for collected packages: mnist1d
#   Building wheel for mnist1d (pyproject.toml) ... done
#   Created wheel for mnist1d: filename=mnist1d-0.0.2.post16-py3-none-any.whl size=14665 sha256=c49e7c137605bc13ec303850ea78bbcbd8e43a0beab6c5594a7f3b2a22c0fab1
#   Stored in directory: /tmp/pip-ephem-wheel-cache-xdqwvntj/wheels/18/40/b6/29381fee9b4c80fdbc304d52bb065a7286bbcca5ca2b8737c0
# Successfully built mnist1d
# Installing collected packages: mnist1d
# Successfully installed mnist1d-0.0.2.post16

# %%
import torch, torch.nn as nn
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR
import numpy as np
import matplotlib.pyplot as plt
import mnist1d
import random
random.seed(0)

# Try attaching to GPU -- Use "Change Runtime Type to change to GPUT"
DEVICE = str(torch.device('cuda' if torch.cuda.is_available() else 'cpu'))
print('Using:', DEVICE)
# Out:
# Using: cuda

# %%
args = mnist1d.data.get_dataset_args()
args.num_samples = 8000
args.train_split = 0.5
args.corr_noise_scale = 0.25
args.iid_noise_scale=2e-2
data = mnist1d.data.get_dataset(args, path='./mnist1d_data.pkl', download=False, regenerate=True)

# Add 15% noise to training labels
for c_y in range(len(data['y'])):
    random_number = random.random()
    if random_number < 0.15 :
        random_int = int(random.random() * 10)
        data['y'][c_y] = random_int

# The training and test input and outputs are in
# data['x'], data['y'], data['x_test'], and data['y_test']
print("Examples in training set: {}".format(len(data['y'])))
print("Examples in test set: {}".format(len(data['y_test'])))
print("Dimensionality of each example: {}".format(data['x'].shape[-1]))
# Out:
# Did or could not load data from ./mnist1d_data.pkl. Rebuilding dataset...
# Examples in training set: 4000
# Examples in test set: 4000
# Dimensionality of each example: 40

# %%
# Initialize the parameters with He initialization
def weights_init(layer_in):
  if isinstance(layer_in, nn.Linear):
    nn.init.kaiming_uniform_(layer_in.weight)
    layer_in.bias.data.fill_(0.0)

# Return an initialized model with two hidden layers and n_hidden hidden units at each
def get_model(n_hidden):

  D_i = 40    # Input dimensions
  D_k = n_hidden   # Hidden dimensions
  D_o = 10    # Output dimensions

  # Define a model with two hidden layers
  # And ReLU activations between them
  model = nn.Sequential(
  nn.Linear(D_i, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_k),
  nn.ReLU(),
  nn.Linear(D_k, D_o))

  # Call the function you just defined
  model.apply(weights_init)

  # Return the model
  return model ;

# %%
def fit_model(model, data, n_epoch):

  # choose cross entropy loss function (equation 5.24)
  loss_function = torch.nn.CrossEntropyLoss()
  # construct SGD optimizer and initialize learning rate and momentum
  # optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
  optimizer = torch.optim.SGD(model.parameters(), lr = 0.01, momentum=0.9)


  x_train = torch.tensor(data['x'].astype('float32'))
  y_train = torch.tensor(data['y'].transpose().astype('long'))
  x_test= torch.tensor(data['x_test'].astype('float32'))
  y_test = torch.tensor(data['y_test'].astype('long'))

  # load the data into a class that creates the batches
  data_loader = DataLoader(TensorDataset(x_train,y_train), batch_size=100, shuffle=True, worker_init_fn=np.random.seed(1))

  for epoch in range(n_epoch):
    # loop over batches
    for i, batch in enumerate(data_loader):
      # retrieve inputs and labels for this batch
      x_batch, y_batch = batch
      # zero the parameter gradients
      optimizer.zero_grad()
      # forward pass -- calculate model output
      pred = model(x_batch)
      # compute the loss
      loss = loss_function(pred, y_batch)
      # backward pass
      loss.backward()
      # SGD update
      optimizer.step()

    # Run whole dataset to get statistics -- normally wouldn't do this
    pred_train = model(x_train)
    pred_test = model(x_test)
    _, predicted_train_class = torch.max(pred_train.data, 1)
    _, predicted_test_class = torch.max(pred_test.data, 1)
    errors_train = 100 - 100 * (predicted_train_class == y_train).float().sum() / len(y_train)
    errors_test= 100 - 100 * (predicted_test_class == y_test).float().sum() / len(y_test)
    losses_train = loss_function(pred_train, y_train).item()
    losses_test= loss_function(pred_test, y_test).item()
    if epoch%100 ==0 :
      print(f'Epoch {epoch:5d}, train loss {losses_train:.6f}, train error {errors_train:3.2f},  test loss {losses_test:.6f}, test error {errors_test:3.2f}')

  return errors_train, errors_test

# %%
def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# %% [markdown]
# The following code produces the double descent curve by training the model with different numbers of hidden units and plotting the test error.
#
# TODO:
#
# *Before* you run the code, and considering that there are 4000 training examples predict:<br>
#
# 1.    At what capacity do you think the training error will become zero?
# 2.   At what capacity do you expect the first minima of the double descent curve to appear?
# 3. At what capacity do you expect the maximum of the double descent curve to appear?

# %%
# This code will take a while (~30 mins on GPU) to run!  Go and make a cup of coffee!

hidden_variables = np.array([2,4,6,8,10,14,18,22,26,30,35,40,45,50,55,60,70,80,90,100,120,140,160,180,200,250,300,400]) ;

errors_train_all = np.zeros_like(hidden_variables)
errors_test_all = np.zeros_like(hidden_variables)
total_weights_all = np.zeros_like(hidden_variables)

# loop over the dataset n_epoch times
n_epoch = 1000

# For each hidden variable size
for c_hidden in range(len(hidden_variables)):
    print(f'Training model with {hidden_variables[c_hidden]:3d} hidden variables')
    # Get a model
    model = get_model(hidden_variables[c_hidden]) ;
    # Count and store number of weights
    total_weights_all[c_hidden] = count_parameters(model)
    # Train the model
    errors_train, errors_test = fit_model(model, data, n_epoch)
    # Store the results
    errors_train_all[c_hidden] = errors_train
    errors_test_all[c_hidden]= errors_test
# Out:
# Training model with   2 hidden variables
# Epoch     0, train loss 2.296661, train error 85.70,  test loss 2.297224, test error 85.30
# Epoch   100, train loss 1.883512, train error 71.72,  test loss 1.727315, test error 69.12
# Epoch   200, train loss 1.866114, train error 70.70,  test loss 1.717914, test error 68.65
# Epoch   300, train loss 1.857997, train error 69.97,  test loss 1.709572, test error 68.25
# Epoch   400, train loss 1.854766, train error 69.82,  test loss 1.703126, test error 67.75
# Epoch   500, train loss 1.854252, train error 69.85,  test loss 1.699764, test error 67.90
# Epoch   600, train loss 1.855833, train error 69.57,  test loss 1.707746, test error 67.35
# Epoch   700, train loss 1.854387, train error 69.88,  test loss 1.706118, test error 67.22
# Epoch   800, train loss 1.856998, train error 70.35,  test loss 1.708282, test error 67.20
# Epoch   900, train loss 1.856820, train error 70.72,  test loss 1.704366, test error 68.12
# Training model with   4 hidden variables
# Epoch     0, train loss 2.295692, train error 89.82,  test loss 2.291833, test error 89.88
# Epoch   100, train loss 1.787111, train error 66.95,  test loss 1.651881, test error 65.15
# Epoch   200, train loss 1.768722, train error 65.43,  test loss 1.628745, test error 64.60
# Epoch   300, train loss 1.760739, train error 64.60,  test loss 1.618702, test error 63.95
# Epoch   400, train loss 1.764694, train error 64.72,  test loss 1.641739, test error 64.12
# Epoch   500, train loss 1.755375, train error 64.18,  test loss 1.625160, test error 64.15
# Epoch   600, train loss 1.753234, train error 64.38,  test loss 1.629707, test error 63.67
# Epoch   700, train loss 1.751636, train error 64.50,  test loss 1.627104, test error 64.05
# Epoch   800, train loss 1.741714, train error 63.70,  test loss 1.619872, test error 63.47
# Epoch   900, train loss 1.739510, train error 64.40,  test loss 1.618770, test error 63.78
# Training model with   6 hidden variables
# Epoch     0, train loss 2.288359, train error 89.88,  test loss 2.296889, test error 90.62
# Epoch   100, train loss 1.727709, train error 62.58,  test loss 1.592909, test error 61.47
# Epoch   200, train loss 1.688073, train error 60.80,  test loss 1.562006, test error 59.67
# Epoch   300, train loss 1.649076, train error 57.83,  test loss 1.517704, test error 57.55
# Epoch   400, train loss 1.640146, train error 58.72,  test loss 1.510276, test error 56.42
# Epoch   500, train loss 1.635841, train error 58.42,  test loss 1.511768, test error 56.58
# Epoch   600, train loss 1.638385, train error 58.60,  test loss 1.513736, test error 56.20
# Epoch   700, train loss 1.630395, train error 57.70,  test loss 1.510768, test error 55.67
# Epoch   800, train loss 1.629507, train error 57.50,  test loss 1.513912, test error 56.00
# Epoch   900, train loss 1.629828, train error 57.38,  test loss 1.518317, test error 56.88
# Training model with   8 hidden variables
# Epoch     0, train loss 2.292789, train error 86.53,  test loss 2.293298, test error 87.43
# Epoch   100, train loss 1.646804, train error 58.60,  test loss 1.468327, test error 57.38
# Epoch   200, train loss 1.613786, train error 57.53,  test loss 1.454784, test error 56.12
# Epoch   300, train loss 1.583117, train error 56.03,  test loss 1.449521, test error 57.25
# Epoch   400, train loss 1.560600, train error 55.05,  test loss 1.453129, test error 56.12
# Epoch   500, train loss 1.537725, train error 54.75,  test loss 1.453029, test error 56.05
# Epoch   600, train loss 1.536916, train error 54.92,  test loss 1.455219, test error 56.15
# Epoch   700, train loss 1.530814, train error 54.12,  test loss 1.452062, test error 54.58
# Epoch   800, train loss 1.528425, train error 54.08,  test loss 1.455759, test error 55.95
# Epoch   900, train loss 1.518571, train error 53.45,  test loss 1.466888, test error 55.58
# Training model with  10 hidden variables
# Epoch     0, train loss 2.236741, train error 83.18,  test loss 2.213742, test error 80.90
# Epoch   100, train loss 1.526745, train error 51.78,  test loss 1.380826, test error 51.42
# Epoch   200, train loss 1.433824, train error 48.65,  test loss 1.306234, test error 48.47
# Epoch   300, train loss 1.410419, train error 47.03,  test loss 1.289999, test error 47.58
# Epoch   400, train loss 1.402662, train error 47.10,  test loss 1.312829, test error 48.65
# Epoch   500, train loss 1.394029, train error 46.03,  test loss 1.304339, test error 48.28
# Epoch   600, train loss 1.390737, train error 45.83,  test loss 1.314760, test error 47.97
# Epoch   700, train loss 1.388492, train error 44.78,  test loss 1.320715, test error 48.65
# Epoch   800, train loss 1.388771, train error 45.60,  test loss 1.329843, test error 48.60
# Epoch   900, train loss 1.389571, train error 45.50,  test loss 1.324742, test error 48.78
# Training model with  14 hidden variables
# Epoch     0, train loss 2.161862, train error 80.93,  test loss 2.142120, test error 79.95
# Epoch   100, train loss 1.449653, train error 49.25,  test loss 1.344755, test error 51.12
# Epoch   200, train loss 1.370997, train error 46.90,  test loss 1.306015, test error 48.50
# Epoch   300, train loss 1.334875, train error 45.42,  test loss 1.316041, test error 48.95
# Epoch   400, train loss 1.309744, train error 44.75,  test loss 1.334223, test error 49.40
# Epoch   500, train loss 1.298506, train error 44.75,  test loss 1.351866, test error 49.08
# Epoch   600, train loss 1.287934, train error 43.97,  test loss 1.371828, test error 49.78
# Epoch   700, train loss 1.287297, train error 44.65,  test loss 1.399039, test error 50.28
# Epoch   800, train loss 1.273122, train error 43.38,  test loss 1.390654, test error 50.30
# Epoch   900, train loss 1.279667, train error 43.95,  test loss 1.404256, test error 50.55
# Training model with  18 hidden variables
# Epoch     0, train loss 2.190742, train error 80.15,  test loss 2.165134, test error 78.97
# Epoch   100, train loss 1.324676, train error 43.42,  test loss 1.263316, test error 46.28
# Epoch   200, train loss 1.220701, train error 41.22,  test loss 1.280875, test error 47.58
# Epoch   300, train loss 1.175854, train error 40.08,  test loss 1.328797, test error 49.00
# Epoch   400, train loss 1.150114, train error 39.78,  test loss 1.358627, test error 49.28
# Epoch   500, train loss 1.132800, train error 38.72,  test loss 1.395145, test error 49.88
# Epoch   600, train loss 1.161958, train error 39.95,  test loss 1.464507, test error 51.50
# Epoch   700, train loss 1.134011, train error 38.80,  test loss 1.466843, test error 51.28
# Epoch   800, train loss 1.131518, train error 38.88,  test loss 1.481726, test error 50.65
# Epoch   900, train loss 1.131697, train error 38.67,  test loss 1.492072, test error 51.83
# Training model with  22 hidden variables
# Epoch     0, train loss 2.189498, train error 81.43,  test loss 2.179252, test error 81.68
# Epoch   100, train loss 1.253282, train error 41.42,  test loss 1.279189, test error 47.47
# Epoch   200, train loss 1.144844, train error 38.55,  test loss 1.364642, test error 49.42
# Epoch   300, train loss 1.101119, train error 37.60,  test loss 1.444603, test error 50.67
# Epoch   400, train loss 1.068973, train error 35.90,  test loss 1.504873, test error 51.42
# Epoch   500, train loss 1.059782, train error 35.93,  test loss 1.568718, test error 51.85
# Epoch   600, train loss 1.037751, train error 35.70,  test loss 1.619805, test error 52.20
# Epoch   700, train loss 1.029103, train error 35.47,  test loss 1.638091, test error 51.50
# Epoch   800, train loss 1.009141, train error 34.70,  test loss 1.704464, test error 51.58
# Epoch   900, train loss 1.004444, train error 34.32,  test loss 1.719921, test error 51.10
# Training model with  26 hidden variables
# Epoch     0, train loss 2.175231, train error 81.53,  test loss 2.157531, test error 80.30
# Epoch   100, train loss 1.183844, train error 39.58,  test loss 1.332038, test error 48.03
# Epoch   200, train loss 1.028033, train error 34.03,  test loss 1.456511, test error 48.30
# Epoch   300, train loss 0.952366, train error 32.07,  test loss 1.629124, test error 50.47
# Epoch   400, train loss 0.897916, train error 30.20,  test loss 1.760159, test error 51.20
# Epoch   500, train loss 0.880888, train error 29.80,  test loss 1.862389, test error 51.92
# Epoch   600, train loss 0.854269, train error 29.03,  test loss 1.943632, test error 52.20
# Epoch   700, train loss 0.841259, train error 28.05,  test loss 2.014283, test error 52.47
# Epoch   800, train loss 0.835680, train error 28.75,  test loss 2.067198, test error 52.28
# Epoch   900, train loss 0.830961, train error 28.20,  test loss 2.146046, test error 54.58
# Training model with  30 hidden variables
# Epoch     0, train loss 2.077204, train error 78.30,  test loss 2.017416, test error 78.15
# Epoch   100, train loss 1.115657, train error 36.62,  test loss 1.326928, test error 48.78
# Epoch   200, train loss 0.923700, train error 31.12,  test loss 1.525805, test error 51.20
# Epoch   300, train loss 0.829621, train error 28.75,  test loss 1.683424, test error 52.20
# Epoch   400, train loss 0.779441, train error 27.22,  test loss 1.847752, test error 53.20
# Epoch   500, train loss 0.735150, train error 25.28,  test loss 1.970201, test error 53.72
# Epoch   600, train loss 0.714686, train error 24.82,  test loss 2.107815, test error 53.95
# Epoch   700, train loss 0.699796, train error 24.45,  test loss 2.215601, test error 55.10
# Epoch   800, train loss 0.704725, train error 23.80,  test loss 2.285549, test error 53.83
# Epoch   900, train loss 0.674449, train error 23.12,  test loss 2.404795, test error 55.03
# Training model with  35 hidden variables
# Epoch     0, train loss 2.127961, train error 78.25,  test loss 2.094571, test error 77.62
# Epoch   100, train loss 1.004876, train error 32.65,  test loss 1.441671, test error 51.40
# Epoch   200, train loss 0.790323, train error 25.43,  test loss 1.795905, test error 53.53
# Epoch   300, train loss 0.705899, train error 24.75,  test loss 2.137954, test error 54.15
# Epoch   400, train loss 0.618632, train error 21.18,  test loss 2.453739, test error 54.97
# Epoch   500, train loss 0.561945, train error 18.43,  test loss 2.784619, test error 55.80
# Epoch   600, train loss 0.529938, train error 17.72,  test loss 3.172433, test error 56.62
# Epoch   700, train loss 0.496549, train error 16.88,  test loss 3.483500, test error 57.67
# Epoch   800, train loss 0.516916, train error 18.12,  test loss 3.767802, test error 58.25
# Epoch   900, train loss 0.464468, train error 16.12,  test loss 4.025755, test error 58.12
# Training model with  40 hidden variables
# Epoch     0, train loss 2.173046, train error 78.75,  test loss 2.169063, test error 79.78
# Epoch   100, train loss 0.927581, train error 30.35,  test loss 1.474991, test error 50.22
# Epoch   200, train loss 0.664025, train error 21.72,  test loss 2.018404, test error 52.75
# Epoch   300, train loss 0.512558, train error 16.30,  test loss 2.578255, test error 54.40
# Epoch   400, train loss 0.417466, train error 13.82,  test loss 3.297182, test error 56.40
# Epoch   500, train loss 0.348922, train error 11.07,  test loss 3.942685, test error 57.03
# Epoch   600, train loss 0.320730, train error 10.90,  test loss 4.582836, test error 56.30
# Epoch   700, train loss 0.351939, train error 12.10,  test loss 5.193671, test error 56.55
# Epoch   800, train loss 0.263765, train error 8.82,  test loss 5.784438, test error 56.85
# Epoch   900, train loss 0.336575, train error 12.18,  test loss 6.524682, test error 57.75
# Training model with  45 hidden variables
# Epoch     0, train loss 2.061790, train error 77.35,  test loss 2.012928, test error 78.25
# Epoch   100, train loss 0.799919, train error 25.53,  test loss 1.596736, test error 52.20
# Epoch   200, train loss 0.446019, train error 13.12,  test loss 2.447025, test error 53.65
# Epoch   300, train loss 0.269988, train error 7.45,  test loss 3.552303, test error 55.88
# Epoch   400, train loss 0.225621, train error 7.35,  test loss 4.873637, test error 57.10
# Epoch   500, train loss 0.092246, train error 1.93,  test loss 6.227223, test error 57.15
# Epoch   600, train loss 0.019949, train error 0.03,  test loss 7.560756, test error 56.58
# Epoch   700, train loss 0.133369, train error 4.75,  test loss 8.135577, test error 56.22
# Epoch   800, train loss 0.007672, train error 0.00,  test loss 9.052067, test error 56.45
# Epoch   900, train loss 0.005299, train error 0.00,  test loss 9.562543, test error 56.65
# Training model with  50 hidden variables
# Epoch     0, train loss 2.075387, train error 77.85,  test loss 2.029154, test error 76.88
# Epoch   100, train loss 0.710582, train error 21.75,  test loss 1.585957, test error 51.67
# Epoch   200, train loss 0.332087, train error 9.43,  test loss 2.634713, test error 54.35
# Epoch   300, train loss 0.135482, train error 2.50,  test loss 4.257972, test error 57.67
# Epoch   400, train loss 0.025751, train error 0.00,  test loss 5.790732, test error 57.08
# Epoch   500, train loss 0.012131, train error 0.00,  test loss 6.720215, test error 57.42
# Epoch   600, train loss 0.007702, train error 0.00,  test loss 7.310627, test error 57.20
# Epoch   700, train loss 0.005505, train error 0.00,  test loss 7.759802, test error 57.22
# Epoch   800, train loss 0.004225, train error 0.00,  test loss 8.113574, test error 57.10
# Epoch   900, train loss 0.003449, train error 0.00,  test loss 8.403567, test error 57.15
# Training model with  55 hidden variables
# Epoch     0, train loss 2.112068, train error 77.32,  test loss 2.077282, test error 76.55
# Epoch   100, train loss 0.625353, train error 19.20,  test loss 1.533533, test error 49.60
# Epoch   200, train loss 0.165888, train error 2.80,  test loss 2.773027, test error 50.88
# Epoch   300, train loss 0.033588, train error 0.05,  test loss 4.248132, test error 52.85
# Epoch   400, train loss 0.013087, train error 0.00,  test loss 5.122068, test error 53.75
# Epoch   500, train loss 0.007809, train error 0.00,  test loss 5.631371, test error 53.70
# Epoch   600, train loss 0.005413, train error 0.00,  test loss 6.015097, test error 53.60
# Epoch   700, train loss 0.004053, train error 0.00,  test loss 6.309360, test error 53.62
# Epoch   800, train loss 0.003221, train error 0.00,  test loss 6.559629, test error 53.67
# Epoch   900, train loss 0.002644, train error 0.00,  test loss 6.761295, test error 53.67
# Training model with  60 hidden variables
# Epoch     0, train loss 2.044492, train error 76.85,  test loss 1.984410, test error 77.12
# Epoch   100, train loss 0.550855, train error 16.05,  test loss 1.780257, test error 51.95
# Epoch   200, train loss 0.132599, train error 2.62,  test loss 3.397494, test error 54.88
# Epoch   300, train loss 0.019735, train error 0.00,  test loss 4.737385, test error 54.12
# Epoch   400, train loss 0.009269, train error 0.00,  test loss 5.460527, test error 54.55
# Epoch   500, train loss 0.005854, train error 0.00,  test loss 5.928907, test error 54.50
# Epoch   600, train loss 0.004207, train error 0.00,  test loss 6.272328, test error 54.38
# Epoch   700, train loss 0.003222, train error 0.00,  test loss 6.547832, test error 54.42
# Epoch   800, train loss 0.002590, train error 0.00,  test loss 6.770112, test error 54.25
# Epoch   900, train loss 0.002155, train error 0.00,  test loss 6.962096, test error 54.25
# Training model with  70 hidden variables
# Epoch     0, train loss 2.030402, train error 75.85,  test loss 1.964247, test error 76.68
# Epoch   100, train loss 0.367219, train error 9.50,  test loss 2.044800, test error 53.80
# Epoch   200, train loss 0.034410, train error 0.00,  test loss 3.801578, test error 55.10
# Epoch   300, train loss 0.011516, train error 0.00,  test loss 4.656354, test error 55.50
# Epoch   400, train loss 0.006296, train error 0.00,  test loss 5.139747, test error 55.58
# Epoch   500, train loss 0.004235, train error 0.00,  test loss 5.464560, test error 55.80
# Epoch   600, train loss 0.003144, train error 0.00,  test loss 5.718549, test error 55.67
# Epoch   700, train loss 0.002455, train error 0.00,  test loss 5.918808, test error 55.75
# Epoch   800, train loss 0.002009, train error 0.00,  test loss 6.087368, test error 55.65
# Epoch   900, train loss 0.001688, train error 0.00,  test loss 6.233976, test error 55.85
# Training model with  80 hidden variables
# Epoch     0, train loss 2.005783, train error 74.50,  test loss 1.907189, test error 73.05
# Epoch   100, train loss 0.240919, train error 4.80,  test loss 2.002612, test error 49.80
# Epoch   200, train loss 0.020606, train error 0.00,  test loss 3.314461, test error 52.38
# Epoch   300, train loss 0.008087, train error 0.00,  test loss 3.848473, test error 52.40
# Epoch   400, train loss 0.004765, train error 0.00,  test loss 4.171751, test error 52.45
# Epoch   500, train loss 0.003284, train error 0.00,  test loss 4.396551, test error 52.40
# Epoch   600, train loss 0.002468, train error 0.00,  test loss 4.570578, test error 52.45
# Epoch   700, train loss 0.001966, train error 0.00,  test loss 4.713201, test error 52.33
# Epoch   800, train loss 0.001615, train error 0.00,  test loss 4.834058, test error 52.42
# Epoch   900, train loss 0.001364, train error 0.00,  test loss 4.936204, test error 52.45
# Training model with  90 hidden variables
# Epoch     0, train loss 1.989835, train error 73.55,  test loss 1.939028, test error 75.18
# Epoch   100, train loss 0.156885, train error 1.75,  test loss 2.216129, test error 52.22
# Epoch   200, train loss 0.014750, train error 0.00,  test loss 3.245847, test error 51.05
# Epoch   300, train loss 0.006463, train error 0.00,  test loss 3.680935, test error 51.10
# Epoch   400, train loss 0.003960, train error 0.00,  test loss 3.946990, test error 51.00
# Epoch   500, train loss 0.002774, train error 0.00,  test loss 4.142637, test error 51.10
# Epoch   600, train loss 0.002111, train error 0.00,  test loss 4.294605, test error 51.10
# Epoch   700, train loss 0.001688, train error 0.00,  test loss 4.419045, test error 51.12
# Epoch   800, train loss 0.001397, train error 0.00,  test loss 4.524676, test error 51.05
# Epoch   900, train loss 0.001187, train error 0.00,  test loss 4.615975, test error 50.85
# Training model with 100 hidden variables
# Epoch     0, train loss 2.019864, train error 75.72,  test loss 1.960766, test error 75.03
# Epoch   100, train loss 0.101403, train error 0.40,  test loss 2.218191, test error 51.50
# Epoch   200, train loss 0.012287, train error 0.00,  test loss 3.073245, test error 52.12
# Epoch   300, train loss 0.005739, train error 0.00,  test loss 3.435734, test error 51.92
# Epoch   400, train loss 0.003565, train error 0.00,  test loss 3.665825, test error 51.95
# Epoch   500, train loss 0.002536, train error 0.00,  test loss 3.831543, test error 51.78
# Epoch   600, train loss 0.001939, train error 0.00,  test loss 3.961092, test error 51.75
# Epoch   700, train loss 0.001558, train error 0.00,  test loss 4.069006, test error 51.80
# Epoch   800, train loss 0.001293, train error 0.00,  test loss 4.158744, test error 51.72
# Epoch   900, train loss 0.001101, train error 0.00,  test loss 4.237657, test error 51.85
# Training model with 120 hidden variables
# Epoch     0, train loss 1.955600, train error 71.80,  test loss 1.914028, test error 73.90
# Epoch   100, train loss 0.052848, train error 0.03,  test loss 2.190429, test error 49.38
# Epoch   200, train loss 0.009563, train error 0.00,  test loss 2.795903, test error 49.40
# Epoch   300, train loss 0.004730, train error 0.00,  test loss 3.071148, test error 49.65
# Epoch   400, train loss 0.003009, train error 0.00,  test loss 3.250469, test error 49.78
# Epoch   500, train loss 0.002166, train error 0.00,  test loss 3.381555, test error 49.95
# Epoch   600, train loss 0.001673, train error 0.00,  test loss 3.484408, test error 50.00
# Epoch   700, train loss 0.001351, train error 0.00,  test loss 3.570069, test error 49.92
# Epoch   800, train loss 0.001127, train error 0.00,  test loss 3.643299, test error 49.95
# Epoch   900, train loss 0.000964, train error 0.00,  test loss 3.707118, test error 49.97
# Training model with 140 hidden variables
# Epoch     0, train loss 1.949655, train error 72.15,  test loss 1.874015, test error 71.68
# Epoch   100, train loss 0.036708, train error 0.00,  test loss 2.148385, test error 49.28
# Epoch   200, train loss 0.008270, train error 0.00,  test loss 2.644660, test error 49.83
# Epoch   300, train loss 0.004242, train error 0.00,  test loss 2.875752, test error 49.80
# Epoch   400, train loss 0.002750, train error 0.00,  test loss 3.029179, test error 49.58
# Epoch   500, train loss 0.001998, train error 0.00,  test loss 3.142667, test error 49.53
# Epoch   600, train loss 0.001552, train error 0.00,  test loss 3.234034, test error 49.60
# Epoch   700, train loss 0.001259, train error 0.00,  test loss 3.310446, test error 49.70
# Epoch   800, train loss 0.001054, train error 0.00,  test loss 3.375149, test error 49.65
# Epoch   900, train loss 0.000903, train error 0.00,  test loss 3.431213, test error 49.60
# Training model with 160 hidden variables
# Epoch     0, train loss 1.942831, train error 71.45,  test loss 1.874592, test error 73.82
# Epoch   100, train loss 0.029107, train error 0.00,  test loss 2.185373, test error 49.33
# Epoch   200, train loss 0.007175, train error 0.00,  test loss 2.604443, test error 49.20
# Epoch   300, train loss 0.003761, train error 0.00,  test loss 2.812450, test error 49.47
# Epoch   400, train loss 0.002473, train error 0.00,  test loss 2.951395, test error 49.58
# Epoch   500, train loss 0.001809, train error 0.00,  test loss 3.055261, test error 49.62
# Epoch   600, train loss 0.001412, train error 0.00,  test loss 3.137861, test error 49.62
# Epoch   700, train loss 0.001150, train error 0.00,  test loss 3.206887, test error 49.50
# Epoch   800, train loss 0.000965, train error 0.00,  test loss 3.265786, test error 49.47
# Epoch   900, train loss 0.000829, train error 0.00,  test loss 3.317643, test error 49.45
# Training model with 180 hidden variables
# Epoch     0, train loss 1.934019, train error 70.53,  test loss 1.845718, test error 70.75
# Epoch   100, train loss 0.025079, train error 0.00,  test loss 2.081173, test error 47.80
# Epoch   200, train loss 0.006692, train error 0.00,  test loss 2.442756, test error 47.83
# Epoch   300, train loss 0.003570, train error 0.00,  test loss 2.625223, test error 47.80
# Epoch   400, train loss 0.002364, train error 0.00,  test loss 2.747910, test error 47.75
# Epoch   500, train loss 0.001737, train error 0.00,  test loss 2.840412, test error 47.70
# Epoch   600, train loss 0.001360, train error 0.00,  test loss 2.913246, test error 47.72
# Epoch   700, train loss 0.001110, train error 0.00,  test loss 2.973886, test error 47.85
# Epoch   800, train loss 0.000933, train error 0.00,  test loss 3.026556, test error 47.90
# Epoch   900, train loss 0.000802, train error 0.00,  test loss 3.071838, test error 47.92
# Training model with 200 hidden variables
# Epoch     0, train loss 1.911251, train error 70.57,  test loss 1.807093, test error 70.68
# Epoch   100, train loss 0.021998, train error 0.00,  test loss 1.986075, test error 47.60
# Epoch   200, train loss 0.006252, train error 0.00,  test loss 2.307766, test error 48.17
# Epoch   300, train loss 0.003385, train error 0.00,  test loss 2.470853, test error 48.05
# Epoch   400, train loss 0.002257, train error 0.00,  test loss 2.581289, test error 48.12
# Epoch   500, train loss 0.001665, train error 0.00,  test loss 2.663686, test error 48.15
# Epoch   600, train loss 0.001307, train error 0.00,  test loss 2.730487, test error 48.17
# Epoch   700, train loss 0.001069, train error 0.00,  test loss 2.785887, test error 48.08
# Epoch   800, train loss 0.000900, train error 0.00,  test loss 2.833290, test error 48.08
# Epoch   900, train loss 0.000774, train error 0.00,  test loss 2.875272, test error 48.08
# Training model with 250 hidden variables
# Epoch     0, train loss 1.943373, train error 71.28,  test loss 1.876240, test error 73.35
# Epoch   100, train loss 0.016869, train error 0.00,  test loss 1.917220, test error 47.12
# Epoch   200, train loss 0.005314, train error 0.00,  test loss 2.171992, test error 47.65
# Epoch   300, train loss 0.002963, train error 0.00,  test loss 2.305187, test error 47.40
# Epoch   400, train loss 0.002001, train error 0.00,  test loss 2.396692, test error 47.38
# Epoch   500, train loss 0.001489, train error 0.00,  test loss 2.466766, test error 47.40
# Epoch   600, train loss 0.001176, train error 0.00,  test loss 2.522884, test error 47.47
# Epoch   700, train loss 0.000966, train error 0.00,  test loss 2.569872, test error 47.45
# Epoch   800, train loss 0.000816, train error 0.00,  test loss 2.609896, test error 47.45
# Epoch   900, train loss 0.000704, train error 0.00,  test loss 2.645692, test error 47.45
# Training model with 300 hidden variables
# Epoch     0, train loss 1.889487, train error 69.25,  test loss 1.814089, test error 70.35
# Epoch   100, train loss 0.014333, train error 0.00,  test loss 1.798846, test error 46.28
# Epoch   200, train loss 0.004783, train error 0.00,  test loss 2.000085, test error 46.08
# Epoch   300, train loss 0.002706, train error 0.00,  test loss 2.111039, test error 46.00
# Epoch   400, train loss 0.001841, train error 0.00,  test loss 2.186870, test error 45.83
# Epoch   500, train loss 0.001377, train error 0.00,  test loss 2.245609, test error 45.80
# Epoch   600, train loss 0.001091, train error 0.00,  test loss 2.292908, test error 45.83
# Epoch   700, train loss 0.000898, train error 0.00,  test loss 2.332781, test error 45.80
# Epoch   800, train loss 0.000760, train error 0.00,  test loss 2.366943, test error 45.80
# Epoch   900, train loss 0.000657, train error 0.00,  test loss 2.397418, test error 45.78
# Training model with 400 hidden variables
# Epoch     0, train loss 1.853643, train error 66.65,  test loss 1.807324, test error 70.28
# Epoch   100, train loss 0.011635, train error 0.00,  test loss 1.760174, test error 46.08
# Epoch   200, train loss 0.004170, train error 0.00,  test loss 1.935736, test error 45.88
# Epoch   300, train loss 0.002417, train error 0.00,  test loss 2.033107, test error 45.88
# Epoch   400, train loss 0.001665, train error 0.00,  test loss 2.101434, test error 45.65
# Epoch   500, train loss 0.001255, train error 0.00,  test loss 2.153430, test error 45.55
# Epoch   600, train loss 0.000999, train error 0.00,  test loss 2.195959, test error 45.58
# Epoch   700, train loss 0.000826, train error 0.00,  test loss 2.231746, test error 45.67
# Epoch   800, train loss 0.000701, train error 0.00,  test loss 2.262435, test error 45.55
# Epoch   900, train loss 0.000607, train error 0.00,  test loss 2.289662, test error 45.58

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming data['y'] is available and contains the training examples
num_training_examples = len(data['y'])

# Find the index where total_weights_all is closest to num_training_examples
closest_index = np.argmin(np.abs(np.array(total_weights_all) - num_training_examples))

# Get the corresponding value of hidden variables
hidden_variable_at_num_training_examples = hidden_variables[closest_index]

# Plot the results
fig, ax = plt.subplots()
ax.plot(hidden_variables, errors_train_all, 'r-', label='train')
ax.plot(hidden_variables, errors_test_all, 'b-', label='test')

# Add a vertical line at the point where total weights equal the number of training examples
ax.axvline(x=hidden_variable_at_num_training_examples, color='g', linestyle='--', label='N(weights) = N(train)')

ax.set_ylim(0, 100)
ax.set_xlabel('No. hidden variables')
ax.set_ylabel('Error')
ax.legend()
plt.show()
